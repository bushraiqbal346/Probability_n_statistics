# %% [markdown]
# # Probability - Coin Flips and Experiments

# %%
import matplotlib 
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np 

import seaborn as sns
sns.set(color_codes=True)
sns.set_style("white")     # See more styling options here: https://seaborn.pydata.org/tutorial/aesthetics.html

# %%
np.random.uniform(low=0.0, high=1.0)
# Out:
# 0.10776845450591532

# %%
# generate a 'flip'
def flip(num = 1):
    flips = [] 
    
    for i in range(num): 
        num = np.random.uniform(low=0.0, high=1.0)      
        if num > 0.75: 
            flips.append('H')             # should be doing yield here if you know 'generators'
        else: 
            flips.append('T')
    return flips

# %%
flip()
# Out:
# ['H']

# %%
flips = flip(10) 
print(flips)
# Out:
# ['T', 'T', 'T', 'T', 'T', 'H', 'T', 'H', 'H', 'T']

# %%
values, counts = np.unique(flips, return_counts=True)

# %%
values, counts
# Out:
# (array(['H', 'T'], dtype='<U1'), array([3, 7]))

# %% [markdown]
# ## Repdoducible 'Randomness'

# %%
# computers are 'deterministic'. You can not do 'random' in computers! 
# So, you start with some 'seed' then do deterministic things 
# this is called pseudo-randomness 

# sometimes you want to suppress this! 

np.random.seed(0)   # random numbers and seed

# %%
np.random.uniform(low=0.0, high=1.0)
# Out:
# 0.7151893663724195

# %%
import matplotlib 
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np 

import seaborn as sns
sns.set(color_codes=True)
sns.set_style("white")     # See more styling options here: https://seaborn.pydata.org/tutorial/aesthetics.html


#np.random.seed(1337)   # random numbers and seed 


# generate a 'flip'
def flip(num = 1):
    flips = [] 
    
    for i in range(num): 
        num = np.random.uniform(low=0.0, high=1.0)      
        if num > 0.75: 
            flips.append('H')             # should be doing yield here if you know 'generators'
        else: 
            flips.append('T')
    return flips


# Flip 
flips = flip(10) 
values, counts = np.unique(flips, return_counts=True)

# print values/stats
# print(flip())
print(flips)
print(values, counts)
# Out:
# ['T', 'T', 'H', 'T', 'H', 'T', 'T', 'T', 'T', 'T']
# ['H' 'T'] [2 8]

# %% [markdown]
# ## Probability of Flips

# %%
from collections import Counter, defaultdict 


def get_freqs(flips): 
    keys = Counter(flips).keys()
    vals = Counter(flips).values()  
    
    # print(keys)
    # print(vals) 
    
    # return dict(zip(keys, vals))     # bug: what if there are no 'H' or no 'T'

    return defaultdict(int, dict(zip(keys, vals)))

# %%
freqs = get_freqs(flips)
print(freqs)
# Out:
# defaultdict(<class 'int'>, {'T': 8, 'H': 2})

# %%
prob_h = freqs['H'] / len(flips)
print(prob_h)
# Out:
# 0.2

# %% [markdown]
# ## Experiment: Prob calculated based on 1 flip upto N flips

# %%
maximum_flips = 1000

probs = [] 
for num_flips in range(1, maximum_flips):
    flips = flip(num_flips)
    freqs = get_freqs(flips)
    prob_h = freqs['H'] / len(flips)

    probs.append(prob_h)
    
# print(probs)

# %%
print(freqs)
# Out:
# defaultdict(<class 'int'>, {'H': 262, 'T': 737})

# %%
plt.plot(probs)
plt.ylabel('Estimated Probability')
plt.xlabel('Number of Flips in Experiment');
plt.title("Calculating Probability over Number of Flips")
sns.despine(offset=10, trim=True);  # move axes away 
plt.show()

# %%
plt.plot(probs[:10])
plt.ylabel('Estimated Probability')
plt.xlabel('Number of Flips in Experiment');
plt.title("Calculating Probability over Number of Flips")
sns.despine(offset=10, trim=True);  # move axes away 
plt.show()

# %%
plt.plot(probs[maximum_flips-10:])
plt.ylabel('Estimated Probability')
plt.xlabel('Number of Flips in Experiment');
plt.title("Calculating Probability over Number of Flips")
sns.despine(offset=10, trim=True);  # move axes away 
plt.show()

# %% [markdown]
# ## Bokeh For Interactive Plots

# %%
# !pip install bokeh
# Out:
# Requirement already satisfied: bokeh in c:\users\dell\documents\tempo_test\state-env\lib\site-packages (3.8.0)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\dell\documents\tempo_test\state-env\lib\site-packages (from bokeh) (3.1.6)
# Requirement already satisfied: contourpy>=1.2 in c:\users\dell\documents\tempo_test\state-env\lib\site-packages (from bokeh) (1.3.1)
# Requirement already satisfied: narwhals>=1.13 in c:\users\dell\documents\tempo_test\state-env\lib\site-packages (from bokeh) (2.10.0)
# Requirement already satisfied: numpy>=1.16 in c:\users\dell\documents\tempo_test\state-env\lib\site-packages (from bokeh) (2.3.3)
# Requirement already satisfied: packaging>=16.8 in c:\users\dell\documents\tempo_test\state-env\lib\site-packages (from bokeh) (25.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\dell\documents\tempo_test\state-env\lib\site-packages (from bokeh) (2.3.3)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\dell\documents\tempo_test\state-env\lib\site-packages (from bokeh) (11.3.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\dell\documents\tempo_test\state-env\lib\site-packages (from bokeh) (6.0.2)
# Requirement already satisfied: tornado>=6.2 in c:\users\dell\documents\tempo_test\state-env\lib\site-packages (from bokeh) (6.5.1)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\dell\documents\tempo_test\state-env\lib\site-packages (from bokeh) (2025.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dell\documents\tempo_test\state-env\lib\site-packages (from Jinja2>=2.9->bokeh) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell\documents\tempo_test\state-env\lib\site-packages (from pandas>=1.2->bokeh) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\documents\tempo_test\state-env\lib\site-packages (from pandas>=1.2->bokeh) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\documents\tempo_test\state-env\lib\site-packages (from pandas>=1.2->bokeh) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\dell\documents\tempo_test\state-env\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.2->bokeh) (1.17.0)

# %%
from bokeh.io import show, output_notebook
from bokeh.plotting import figure

output_notebook()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="b1396f11-8d3d-4337-99ec-60ed1cdb577a">Loading BokehJS ...</span>
#     </div>

# %%
p = figure(title="Simple Line Plot in Bokeh", 
           x_axis_label='Number of Flips in Experiment', 
           y_axis_label='Estimated Probability', 
           width=580, height=380)

# %%
# Add a line renderer with legend and line thickness
x = range(1, maximum_flips)
p.line(x=x, y=probs)

# Show the results
show(p)
# Out:
# ---------------------------------------------------------------------------
# SerializationError                        Traceback (most recent call last)
# Cell In[61], line 6
#       3 p.line(x=x, y=probs)
#       5 # Show the results
# ----> 6 show(p)
#
# File ~\Documents\tempo_test\state-env\Lib\site-packages\bokeh\io\showing.py:157, in show(obj, browser, new, notebook_handle, notebook_url, **kwargs)
#     154 state = curstate()
#     156 if isinstance(obj, UIElement) or isinstance(obj, Sequence):
# --> 157     return _show_with_state(obj, state, browser, new, notebook_handle=notebook_handle)
#     159 def is_application(obj: Any) -> TypeGuard[Application]:
#     160     return getattr(obj, '_is_a_bokeh_application_class', False)
#
# File ~\Documents\tempo_test\state-env\Lib\site-packages\bokeh\io\showing.py:208, in _show_with_state(obj, state, browser, new, notebook_handle)
#     205     shown = True
#     207 if state.file or not shown:
# --> 208     _show_file_with_state(obj, state, new, controller)
#     210 return comms_handle
#
# File ~\Documents\tempo_test\state-env\Lib\site-packages\bokeh\io\showing.py:189, in _show_file_with_state(obj, state, new, controller)
#     185 def _show_file_with_state(obj: UIElement | Sequence[UIElement], state: State, new: BrowserTarget, controller: BrowserLike) -> None:
#     186     '''
#     187
#     188     '''
# --> 189     filename = save(obj, state=state)
#     190     controller.open("file://" + filename, new=NEW_PARAM[new])
#
# File ~\Documents\tempo_test\state-env\Lib\site-packages\bokeh\io\saving.py:98, in save(obj, filename, resources, title, template, state)
#      95 theme = state.document.theme
#      97 filename, resources, title = _get_save_args(state, filename, resources, title)
# ---> 98 _save_helper(obj, filename, resources, title, template, theme)
#      99 return abspath(expanduser(filename))
#
# File ~\Documents\tempo_test\state-env\Lib\site-packages\bokeh\io\saving.py:164, in _save_helper(obj, filename, resources, title, template, theme)
#     160 '''
#     161
#     162 '''
#     163 from ..embed import file_html
# --> 164 html = file_html(obj, resources=resources, title=title, template=template or FILE, theme=theme)
#     166 with open(filename, mode="w", encoding="utf-8") as f:
#     167     f.write(html)
#
# File ~\Documents\tempo_test\state-env\Lib\site-packages\bokeh\embed\standalone.py:358, in file_html(models, resources, title, template, template_variables, theme, suppress_callback_warning, _always_new)
#     355 resources = Resources.build(resources)
#     357 with OutputDocumentFor(models_seq, apply_theme=theme, always_new=_always_new) as doc:
# --> 358     (docs_json, render_items) = standalone_docs_json_and_render_items(models_seq, suppress_callback_warning=suppress_callback_warning)
#     359     title = _title_from_models(models_seq, title)
#     360     bundle = bundle_for_objs_and_resources([doc], resources)
#
# File ~\Documents\tempo_test\state-env\Lib\site-packages\bokeh\embed\util.py:333, in standalone_docs_json_and_render_items(models, suppress_callback_warning)
#     331 docs_json: dict[ID, DocJson] = {}
#     332 for doc, (docid, _) in docs.items():
# --> 333     docs_json[docid] = doc.to_json(deferred=False)
#     335 render_items: list[RenderItem] = []
#     336 for _, (docid, roots) in docs.items():
#
# File ~\Documents\tempo_test\state-env\Lib\site-packages\bokeh\document\document.py:766, in Document.to_json(self, deferred)
#     764 defs = serializer.encode(data_models)
#     765 config = serializer.encode(self._config)
# --> 766 roots = serializer.encode(self._roots)
#     767 callbacks = serializer.encode(self.callbacks._js_event_callbacks)
#     769 doc_json = DocJson(
#     770     version=__version__,
#     771     title=self.title,
#     772     config=config,
#     773     roots=roots,
#     774 )
#
# File ~\Documents\tempo_test\state-env\Lib\site-packages\bokeh\core\serialization.py:265, in Serializer.encode(self, obj)
#     263 self._circular[ident] = obj
#     264 try:
# --> 265     return self._encode(obj)
#     266 finally:
#     267     if ident in self._circular:
#
# File ~\Documents\tempo_test\state-env\Lib\site-packages\bokeh\core\serialization.py:291, in Serializer._encode(self, obj)
#     289     return self._encode_tuple(obj)
#     290 elif isinstance(obj, list):
# --> 291     return self._encode_list(obj)
#     292 elif isinstance(obj, set):
#     293     return self._encode_set(obj)
#
# File ~\Documents\tempo_test\state-env\Lib\site-packages\bokeh\core\serialization.py:339, in Serializer._encode_list(self, obj)
#     338 def _encode_list(self, obj: list[Any]) -> ArrayRepLike:
# --> 339     return [self.encode(item) for item in obj]
#
# File ~\Documents\tempo_test\state-env\Lib\site-packages\bokeh\core\serialization.py:265, in Serializer.encode(self, obj)
#     263 self._circular[ident] = obj
#     264 try:
# --> 265     return self._encode(obj)
#     266 finally:
#     267     if ident in self._circular:
#
# File ~\Documents\tempo_test\state-env\Lib\site-packages\bokeh\core\serialization.py:275, in Serializer._encode(self, obj)
#     273 def _encode(self, obj: Any) -> AnyRep:
#     274     if isinstance(obj, Serializable):
# --> 275         return obj.to_serializable(self)
#     276     elif (encoder := self._encoders.get(type(obj))) is not None:
#     277         return encoder(obj, self)
#
# File ~\Documents\tempo_test\state-env\Lib\site-packages\bokeh\model\model.py:546, in Model.to_serializable(self, serializer)
#     543 def to_serializable(self, serializer: Serializer) -> ObjectRefRep:
#     544     serializer.add_ref(self, self.ref)
# --> 546     super_rep = super().to_serializable(serializer)
#     547     rep = ObjectRefRep(
#     548         type="object",
#     549         name=super_rep["name"],
#     550         id=self.id,
#     551     )
#     553     attributes = super_rep.get("attributes")
#
# File ~\Documents\tempo_test\state-env\Lib\site-packages\bokeh\core\has_props.py:416, in HasProps.to_serializable(self, serializer)
#     410 rep = ObjectRep(
#     411     type="object",
#     412     name=self.__qualified_model__,
#     413 )
#     415 properties = self.properties_with_values(include_defaults=settings.serialize_include_defaults())
# --> 416 attributes = {key: serializer.encode(val) for key, val in properties.items()}
#     418 if attributes:
#     419     rep["attributes"] = attributes
#
# File ~\Documents\tempo_test\state-env\Lib\site-packages\bokeh\core\serialization.py:265, in Serializer.encode(self, obj)
#     263 self._circular[ident] = obj
#     264 try:
# --> 265     return self._encode(obj)
#     266 finally:
#     267     if ident in self._circular:
#
# File ~\Documents\tempo_test\state-env\Lib\site-packages\bokeh\core\serialization.py:291, in Serializer._encode(self, obj)
#     289     return self._encode_tuple(obj)
#     290 elif isinstance(obj, list):
# --> 291     return self._encode_list(obj)
#     292 elif isinstance(obj, set):
#     293     return self._encode_set(obj)
#
# File ~\Documents\tempo_test\state-env\Lib\site-packages\bokeh\core\serialization.py:339, in Serializer._encode_list(self, obj)
#     338 def _encode_list(self, obj: list[Any]) -> ArrayRepLike:
# --> 339     return [self.encode(item) for item in obj]
#
# File ~\Documents\tempo_test\state-env\Lib\site-packages\bokeh\core\serialization.py:265, in Serializer.encode(self, obj)
#     263 self._circular[ident] = obj
#     264 try:
# --> 265     return self._encode(obj)
#     266 finally:
#     267     if ident in self._circular:
#
# File ~\Documents\tempo_test\state-env\Lib\site-packages\bokeh\core\serialization.py:275, in Serializer._encode(self, obj)
#     273 def _encode(self, obj: Any) -> AnyRep:
#     274     if isinstance(obj, Serializable):
# --> 275         return obj.to_serializable(self)
#     276     elif (encoder := self._encoders.get(type(obj))) is not None:
#     277         return encoder(obj, self)
#
# File ~\Documents\tempo_test\state-env\Lib\site-packages\bokeh\model\model.py:546, in Model.to_serializable(self, serializer)
#     543 def to_serializable(self, serializer: Serializer) -> ObjectRefRep:
#     544     serializer.add_ref(self, self.ref)
# --> 546     super_rep = super().to_serializable(serializer)
#     547     rep = ObjectRefRep(
#     548         type="object",
#     549         name=super_rep["name"],
#     550         id=self.id,
#     551     )
#     553     attributes = super_rep.get("attributes")
#
# File ~\Documents\tempo_test\state-env\Lib\site-packages\bokeh\core\has_props.py:416, in HasProps.to_serializable(self, serializer)
#     410 rep = ObjectRep(
#     411     type="object",
#     412     name=self.__qualified_model__,
#     413 )
#     415 properties = self.properties_with_values(include_defaults=settings.serialize_include_defaults())
# --> 416 attributes = {key: serializer.encode(val) for key, val in properties.items()}
#     418 if attributes:
#     419     rep["attributes"] = attributes
#
# File ~\Documents\tempo_test\state-env\Lib\site-packages\bokeh\core\serialization.py:265, in Serializer.encode(self, obj)
#     263 self._circular[ident] = obj
#     264 try:
# --> 265     return self._encode(obj)
#     266 finally:
#     267     if ident in self._circular:
#
# File ~\Documents\tempo_test\state-env\Lib\site-packages\bokeh\core\serialization.py:275, in Serializer._encode(self, obj)
#     273 def _encode(self, obj: Any) -> AnyRep:
#     274     if isinstance(obj, Serializable):
# --> 275         return obj.to_serializable(self)
#     276     elif (encoder := self._encoders.get(type(obj))) is not None:
#     277         return encoder(obj, self)
#
# File ~\Documents\tempo_test\state-env\Lib\site-packages\bokeh\model\model.py:546, in Model.to_serializable(self, serializer)
#     543 def to_serializable(self, serializer: Serializer) -> ObjectRefRep:
#     544     serializer.add_ref(self, self.ref)
# --> 546     super_rep = super().to_serializable(serializer)
#     547     rep = ObjectRefRep(
#     548         type="object",
#     549         name=super_rep["name"],
#     550         id=self.id,
#     551     )
#     553     attributes = super_rep.get("attributes")
#
# File ~\Documents\tempo_test\state-env\Lib\site-packages\bokeh\core\has_props.py:416, in HasProps.to_serializable(self, serializer)
#     410 rep = ObjectRep(
#     411     type="object",
#     412     name=self.__qualified_model__,
#     413 )
#     415 properties = self.properties_with_values(include_defaults=settings.serialize_include_defaults())
# --> 416 attributes = {key: serializer.encode(val) for key, val in properties.items()}
#     418 if attributes:
#     419     rep["attributes"] = attributes
#
# File ~\Documents\tempo_test\state-env\Lib\site-packages\bokeh\core\serialization.py:265, in Serializer.encode(self, obj)
#     263 self._circular[ident] = obj
#     264 try:
# --> 265     return self._encode(obj)
#     266 finally:
#     267     if ident in self._circular:
#
# File ~\Documents\tempo_test\state-env\Lib\site-packages\bokeh\core\serialization.py:295, in Serializer._encode(self, obj)
#     293     return self._encode_set(obj)
#     294 elif isinstance(obj, dict):
# --> 295     return self._encode_dict(obj)
#     296 elif isinstance(obj, SimpleNamespace):
#     297     return self._encode_struct(obj)
#
# File ~\Documents\tempo_test\state-env\Lib\site-packages\bokeh\core\serialization.py:356, in Serializer._encode_dict(self, obj)
#     352     result = MapRep(type="map")
#     353 else:
#     354     result = MapRep(
#     355         type="map",
# --> 356         entries=[(self.encode(key), self.encode(val)) for key, val in obj.items()],
#     357     )
#     359 return result
#
# File ~\Documents\tempo_test\state-env\Lib\site-packages\bokeh\core\serialization.py:265, in Serializer.encode(self, obj)
#     263 self._circular[ident] = obj
#     264 try:
# --> 265     return self._encode(obj)
#     266 finally:
#     267     if ident in self._circular:
#
# File ~\Documents\tempo_test\state-env\Lib\site-packages\bokeh\core\serialization.py:312, in Serializer._encode(self, obj)
#     310     return self._encode_dataclass(obj)
#     311 else:
# --> 312     return self._encode_other(obj)
#
# File ~\Documents\tempo_test\state-env\Lib\site-packages\bokeh\core\serialization.py:485, in Serializer._encode_other(self, obj)
#     482 if hasattr(obj, "__array__") and isinstance(arr := obj.__array__(), np.ndarray):
#     483     return self._encode_ndarray(arr)
# --> 485 self.error(f"can't serialize {type(obj)}")
#
# File ~\Documents\tempo_test\state-env\Lib\site-packages\bokeh\core\serialization.py:488, in Serializer.error(self, message)
#     487 def error(self, message: str) -> NoReturn:
# --> 488     raise SerializationError(message)
#
# SerializationError: can't serialize <class 'range'>

# %%
from bokeh.plotting import figure, show

# Example data
maximum_flips = 20
probs = [0.5 + (i/100) for i in range(1, maximum_flips)]

# Create figure
p = figure(title="Simple Line Plot in Bokeh",
           x_axis_label='Number of Flips in Experiment',
           y_axis_label='Estimated Probability',
           width=580, height=380)

# Convert range to list
x = list(range(1, maximum_flips))

# Add line
p.line(x=x, y=probs, line_width=2, color="blue")

# Show plot
show(p)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[57], line 20
#      17 p.line(x=x, y=probs, line_width=2, color="blue")
#      19 # Show plot
# ---> 20 show(p)
#
# File ~\Documents\tempo_test\state-env\Lib\site-packages\bokeh\io\showing.py:157, in show(obj, browser, new, notebook_handle, notebook_url, **kwargs)
#     154 state = curstate()
#     156 if isinstance(obj, UIElement) or isinstance(obj, Sequence):
# --> 157     return _show_with_state(obj, state, browser, new, notebook_handle=notebook_handle)
#     159 def is_application(obj: Any) -> TypeGuard[Application]:
#     160     return getattr(obj, '_is_a_bokeh_application_class', False)
#
# File ~\Documents\tempo_test\state-env\Lib\site-packages\bokeh\io\showing.py:204, in _show_with_state(obj, state, browser, new, notebook_handle)
#     202 if state.notebook:
#     203     assert state.notebook_type is not None
# --> 204     comms_handle = run_notebook_hook(state.notebook_type, 'doc', obj, state, notebook_handle)
#     205     shown = True
#     207 if state.file or not shown:
#
# File ~\Documents\tempo_test\state-env\Lib\site-packages\bokeh\io\notebook.py:371, in run_notebook_hook(notebook_type, action, *args, **kwargs)
#     369 if _HOOKS[notebook_type][action] is None:
#     370     raise RuntimeError(f"notebook hook for {notebook_type!r} did not install {action!r} action")
# --> 371 return _HOOKS[notebook_type][action](*args, **kwargs)
#
# File ~\Documents\tempo_test\state-env\Lib\site-packages\bokeh\io\notebook.py:603, in show_doc(obj, state, notebook_handle)
#     599 '''
#     600
#     601 '''
#     602 if obj not in state.document.roots:
# --> 603     state.document.add_root(obj)
#     605 from ..embed.notebook import notebook_content
#     606 comms_target = make_id() if notebook_handle else None
#
# File ~\Documents\tempo_test\state-env\Lib\site-packages\bokeh\document\document.py:331, in Document.add_root(self, model, setter)
#     328 if model in self._roots:
#     329     return
# --> 331 with self.models.freeze():
#     332     self._roots.append(model)
#     334 self.callbacks.trigger_on_change(RootAddedEvent(self, model, setter))
#
# File ~\Documents\tempo_test\state-env\Lib\contextlib.py:148, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     146 if typ is None:
#     147     try:
# --> 148         next(self.gen)
#     149     except StopIteration:
#     150         return False
#
# File ~\Documents\tempo_test\state-env\Lib\site-packages\bokeh\document\models.py:135, in DocumentModelManager.freeze(self)
#     133 self._push_freeze()
#     134 yield
# --> 135 self._pop_freeze()
#
# File ~\Documents\tempo_test\state-env\Lib\site-packages\bokeh\document\models.py:288, in DocumentModelManager._pop_freeze(self)
#     286 self._freeze_count -= 1
#     287 if self._freeze_count == 0:
# --> 288     self.recompute()
#
# File ~\Documents\tempo_test\state-env\Lib\site-packages\bokeh\document\models.py:235, in DocumentModelManager.recompute(self)
#     232     md._detach_document()
#     234 for ma in to_attach:
# --> 235     ma._attach_document(document)
#     236     self._new_models.add(ma)
#     238 self._models = recomputed
#
# File ~\Documents\tempo_test\state-env\Lib\site-packages\bokeh\model\model.py:596, in Model._attach_document(self, doc)
#     593     return
#     595 if self.document is not None:
# --> 596     raise RuntimeError(f"Models must be owned by only a single document, {self!r} is already in a doc")
#     598 doc.theme.apply_to_model(self)
#     599 self.document = doc
#
# RuntimeError: Models must be owned by only a single document, AllIndices(id='p1112', ...) is already in a doc
